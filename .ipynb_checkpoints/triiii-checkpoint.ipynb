# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import learning_curve
import seaborn as sns

# %%
data = pd.read_csv('final maybe.csv')

# %%
data
# Out:
#      Unnamed: 0  Number               Sleep                 Appetite  \
# 0             0        1  Less than 3 hours  Significantly decreased
# 1             1        2          3–5 hours  Significantly increased
# 2             2        3  More than 9 hours       Slightly decreased
# 3             3        4  Less than 3 hours  Significantly decreased
# 4             4        5          3–5 hours  Significantly increased
# ..          ...      ...                ...                      ...
# 808         808      809                NaN                      NaN
# 809         809      810                NaN                      NaN
# 810         810      811                NaN                      NaN
# 811         811      812                NaN                      NaN
# 812         812      813                NaN                      NaN
#
#                                               Interest  \
# 0                    I still find joy in my activities
# 1    I feel completely disengaged and indifferent t...
# 2             I notice a dulling of interest sometimes
# 3                    I still find joy in my activities
# 4    I feel completely disengaged and indifferent t...
# ..                                                 ...
# 808                                                NaN
# 809                                                NaN
# 810                                                NaN
# 811                                                NaN
# 812                                                NaN
#
#                                                Fatigue  \
# 0    I am frequently exhausted and struggle to get ...
# 1        I feel energized and capable most of the time
# 2                  I sometimes feel drained but manage
# 3    I am frequently exhausted and struggle to get ...
# 4        I feel energized and capable most of the time
# ..                                                 ...
# 808                                                NaN
# 809                                                NaN
# 810                                                NaN
# 811                                                NaN
# 812                                                NaN
#
#                                          Worthlessness  \
# 0    I frequently feel like a failure and question ...
# 1            I generally feel confident and worthwhile
# 2                          I occasionally doubt myself
# 3    I frequently feel like a failure and question ...
# 4            I generally feel confident and worthwhile
# ..                                                 ...
# 808                                                NaN
# 809                                                NaN
# 810                                                NaN
# 811                                                NaN
# 812                                                NaN
#
#                                          Concentration  \
# 0                      I focus easily and stay engaged
# 1    Concentration is almost impossible, and I feel...
# 2       Distractions sometimes interfere with my focus
# 3                      I focus easily and stay engaged
# 4    Concentration is almost impossible, and I feel...
# ..                                                 ...
# 808                                                NaN
# 809                                                NaN
# 810                                                NaN
# 811                                                NaN
# 812                                                NaN
#
#                                              Agitation    Suicidal Ideation  \
# 0    I am frequently overwhelmed by restlessness an...    Pretty much daily
# 1                              I feel calm and settled                Never
# 2                 I sometimes feel restless or fidgety  Once in a blue moon
# 3    I am frequently overwhelmed by restlessness an...    Pretty much daily
# 4                              I feel calm and settled                Never
# ..                                                 ...                  ...
# 808                                                NaN                  NaN
# 809                                                NaN                  NaN
# 810                                                NaN                  NaN
# 811                                                NaN                  NaN
# 812                                                NaN                  NaN
#
#                Sleep Disturbance                    Aggression  \
# 0              Sleep like a baby        Angry almost every day
# 1    Barely sleep at all anymore                     Very calm
# 2     Occasionally toss and turn  A little irritated sometimes
# 3              Sleep like a baby        Angry almost every day
# 4    Barely sleep at all anymore                     Very calm
# ..                           ...                           ...
# 808                          NaN                           NaN
# 809                          NaN                           NaN
# 810                          NaN                           NaN
# 811                          NaN                           NaN
# 812                          NaN                           NaN
#
#                         Panic Attacks                           Hopelessness  \
# 0    Almost every day, out of nowhere     Always – I feel hopeless every day
# 1                       Never happens  Almost never – I usually feel hopeful
# 2         Rarely, maybe once or twice  Sometimes – I feel stuck now and then
# 3    Almost every day, out of nowhere     Always – I feel hopeless every day
# 4                       Never happens  Almost never – I usually feel hopeful
# ..                                ...                                    ...
# 808                               NaN                                    NaN
# 809                               NaN                                    NaN
# 810                               NaN                                    NaN
# 811                               NaN                                    NaN
# 812                               NaN                                    NaN
#
#                             Restlessness  \
# 0    I constantly feel uneasy or on edge
# 1           I feel calm most of the time
# 2              It happens, but not often
# 3    I constantly feel uneasy or on edge
# 4           I feel calm most of the time
# ..                                   ...
# 808                                  NaN
# 809                                  NaN
# 810                                  NaN
# 811                                  NaN
# 812                                  NaN
#
#                                             Low Energy     Depression State
# 0    I frequently feel completely exhausted and inc...  Moderate Depression
# 1    I usually feel energized and motivated through...  Moderate Depression
# 2    I sometimes feel a bit tired, but it doesn't a...    Severe Depression
# 3    I frequently feel completely exhausted and inc...  Moderate Depression
# 4    I usually feel energized and motivated through...  Moderate Depression
# ..                                                 ...                  ...
# 808                                                NaN                  NaN
# 809                                                NaN                  NaN
# 810                                                NaN                  NaN
# 811                                                NaN                  NaN
# 812                                                NaN                  NaN
#
# [813 rows x 17 columns]

# %% [markdown]
# <h1>gotta clean this bruhh</h1>

# %%
data.isna().sum()
# Out:
# Unnamed: 0             0
# Number                 0
# Sleep                290
# Appetite             273
# Interest             273
# Fatigue              290
# Worthlessness        290
# Concentration        273
# Agitation            290
# Suicidal Ideation    290
# Sleep Disturbance    273
# Aggression           290
# Panic Attacks        290
# Hopelessness         290
# Restlessness         290
# Low Energy           288
# Depression State     273
# dtype: int64

# %%
print("Total number of entries:", data.shape[0])
# Out:
# Total number of entries: 813

# %%
data.columns = data.columns.str.strip()  
data = data.drop('Number', axis=1)       
data = data.drop('Unnamed: 0', axis=1) 
print(data.columns)
# Out:
# Index(['Sleep', 'Appetite', 'Interest', 'Fatigue', 'Worthlessness',
#        'Concentration', 'Agitation', 'Suicidal Ideation', 'Sleep Disturbance',
#        'Aggression', 'Panic Attacks', 'Hopelessness', 'Restlessness',
#        'Low Energy', 'Depression State'],
#       dtype='object')

# %%
print("Total number of entries:", data.shape[0])
# Out:
# Total number of entries: 813

# %%
# Step 1: Find fully empty rows
empty_rows = data[data.isnull().all(axis=1)]

# Step 2: Print how many there are
print("Number of fully empty rows:", empty_rows.shape[0])
# Out:
# Number of fully empty rows: 273

# %%
data = data.dropna(how='all')

# %%
data.tail()
# Out:
#                  Sleep                 Appetite  \
# 535          3–5 hours  Significantly increased
# 536  More than 9 hours       Slightly decreased
# 537  Less than 3 hours  Significantly decreased
# 538          3–5 hours  Significantly increased
# 539  More than 9 hours       Slightly decreased
#
#                                               Interest  \
# 535  I feel completely disengaged and indifferent t...
# 536           I notice a dulling of interest sometimes
# 537                  I still find joy in my activities
# 538  I feel completely disengaged and indifferent t...
# 539           I notice a dulling of interest sometimes
#
#                                                Fatigue  \
# 535      I feel energized and capable most of the time
# 536                I sometimes feel drained but manage
# 537  I am frequently exhausted and struggle to get ...
# 538      I feel energized and capable most of the time
# 539                I sometimes feel drained but manage
#
#                                          Worthlessness  \
# 535          I generally feel confident and worthwhile
# 536                        I occasionally doubt myself
# 537  I frequently feel like a failure and question ...
# 538          I generally feel confident and worthwhile
# 539                        I occasionally doubt myself
#
#                                          Concentration  \
# 535  Concentration is almost impossible, and I feel...
# 536     Distractions sometimes interfere with my focus
# 537                    I focus easily and stay engaged
# 538  Concentration is almost impossible, and I feel...
# 539     Distractions sometimes interfere with my focus
#
#                                              Agitation    Suicidal Ideation  \
# 535                            I feel calm and settled                Never
# 536               I sometimes feel restless or fidgety  Once in a blue moon
# 537  I am frequently overwhelmed by restlessness an...    Pretty much daily
# 538                            I feel calm and settled                Never
# 539               I sometimes feel restless or fidgety  Once in a blue moon
#
#                Sleep Disturbance                    Aggression  \
# 535  Barely sleep at all anymore                     Very calm
# 536   Occasionally toss and turn  A little irritated sometimes
# 537            Sleep like a baby        Angry almost every day
# 538  Barely sleep at all anymore                     Very calm
# 539   Occasionally toss and turn  A little irritated sometimes
#
#                         Panic Attacks                           Hopelessness  \
# 535                     Never happens  Almost never – I usually feel hopeful
# 536       Rarely, maybe once or twice  Sometimes – I feel stuck now and then
# 537  Almost every day, out of nowhere     Always – I feel hopeless every day
# 538                     Never happens  Almost never – I usually feel hopeful
# 539       Rarely, maybe once or twice  Sometimes – I feel stuck now and then
#
#                             Restlessness  \
# 535         I feel calm most of the time
# 536            It happens, but not often
# 537  I constantly feel uneasy or on edge
# 538         I feel calm most of the time
# 539            It happens, but not often
#
#                                             Low Energy     Depression State
# 535  I frequently feel completely exhausted and inc...      Mild Depression
# 536  I usually feel energized and motivated through...    Severe Depression
# 537  I sometimes feel a bit tired, but it doesn't a...  Moderate Depression
# 538  I usually feel energized and motivated through...  Moderate Depression
# 539  I sometimes feel a bit tired, but it doesn't a...    Severe Depression

# %%
print(data.isnull().sum())
# Out:
# Sleep                17
# Appetite              0
# Interest              0
# Fatigue              17
# Worthlessness        17
# Concentration         0
# Agitation            17
# Suicidal Ideation    17
# Sleep Disturbance     0
# Aggression           17
# Panic Attacks        17
# Hopelessness         17
# Restlessness         17
# Low Energy           15
# Depression State      0
# dtype: int64

# %%
import random
import pandas as pd

# All your mappings, stored together
mappings = {
    "Sleep": [
        "Less than 3 hours",
        "3–5 hours",
        "5–7 hours",
        "7–9 hours",
        "More than 9 hours"
    ],
    "Appetite": [
        "Significantly decreased",
        "Slightly decreased",
        "No change",
        "Slightly increased",
        "Significantly increased"
    ],
    "Interest": [
        "I still find joy in my activities",
        "I notice a dulling of interest sometimes",
        "Lately, I’ve been feeling disconnected from what I used to enjoy",
        "I rarely feel motivated or interested anymore",
        "I feel completely disengaged and indifferent to my activities"
    ],
    "Fatigue": [
        "I feel energized and capable most of the time",
        "I sometimes feel drained but manage",
        "Lately, fatigue has been a persistent challenge for me",
        "I often feel overwhelmed by exhaustion",
        "I am frequently exhausted and struggle to get through the day"
    ],
    "Worthlessness": [
        "I generally feel confident and worthwhile",
        "I occasionally doubt myself",
        "Lately, negative feelings about myself have increased",
        "I often struggle with feelings of worthlessness",
        "I frequently feel like a failure and question my worth"
    ],
    "Concentration": [
        "I focus easily and stay engaged",
        "Distractions sometimes interfere with my focus",
        "Lately, maintaining concentration has been challenging",
        "I often feel overwhelmed and unable to focus",
        "Concentration is almost impossible, and I feel overwhelmed"
    ],
    "Agitation": [
        "I feel calm and settled",
        "I sometimes feel restless or fidgety",
        "Lately, I’ve been feeling more restless than usual",
        "I often feel anxious, restless, or unable to stay still",
        "I am frequently overwhelmed by restlessness and agitation"
    ],
    "Suicidal Ideation": [
        "Never",
        "Once in a blue moon",
        "Every now and then",
        "Almost every week",
        "Pretty much daily"
    ],
    "Sleep Disturbance": [
        "Sleep like a baby",
        "Occasionally toss and turn",
        "Restless some nights",
        "Almost every night is a struggle",
        "Barely sleep at all anymore"
    ],
    "Aggression": [
        "Very calm",
        "A little irritated sometimes",
        "Get angry once in a while",
        "Feel angry quite often",
        "Angry almost every day"
    ],
    "Panic Attacks": [
        "Never happens",
        "Rarely, maybe once or twice",
        "Sometimes, depends on the day",
        "Often, it catches me off guard",
        "Almost every day, out of nowhere"
    ],
    "Hopelessness": [
        "Almost never – I usually feel hopeful",
        "Sometimes – I feel stuck now and then",
        "Often – I lose hope quite a bit",
        "Most of the time – I feel things won’t improve",
        "Always – I feel hopeless every day"
    ],
    "Restlessness": [
        "I feel calm most of the time",
        "It happens, but not often",
        "I do notice it from time to time",
        "find it hard to stay still or feel settled",
        "I constantly feel uneasy or on edge"
    ],
    "Low Energy": [
        "I usually feel energized and motivated throughout the day",
        "I sometimes feel a bit tired, but it doesn't affect me much",
        "Lately, I’ve been feeling noticeably drained and sluggish",
        "I often struggle with low energy, making daily activities difficult",
        "I frequently feel completely exhausted and incapable of doing what I need to"
    ]
}

# Function to fill NaNs in each column with random choices from mapping
for column, values in mappings.items():
    if column in data.columns:
        data[column] = data[column].apply(
            lambda x: random.choice(values) if pd.isnull(x) else x
        )

# %%
print(data.isnull().sum())
# Out:
# Sleep                0
# Appetite             0
# Interest             0
# Fatigue              0
# Worthlessness        0
# Concentration        0
# Agitation            0
# Suicidal Ideation    0
# Sleep Disturbance    0
# Aggression           0
# Panic Attacks        0
# Hopelessness         0
# Restlessness         0
# Low Energy           0
# Depression State     0
# dtype: int64

# %% [markdown]
# <h1>alright so now as the data is clean , we will begin with encoding , since all the data is ordinal</h1>

# %%
# # Create a dictionary to hold encoders for each column
# encoders = {}
# encoded_data = data.copy()

# # Apply LabelEncoder to every column
# for column in encoded_data.columns:
#     l = LabelEncoder()
#     encoded_data[column] = l.fit_transform(encoded_data[column])
#     encoders[column] = l # Save the encoder for later decoding

# %%
# data["Total_Score"] = encoded_data.sum(axis=1)
# def classify_depression(score):
#     if score <= 14:
#         return 'No Depression'
#     elif score <= 24:
#         return 'Mild Depression'
#     elif score <= 34:
#         return 'Moderate Depression'
#     elif score <= 44:
#         return 'Severe Depression'
#     else:
#         return 'Extremely Severe'

# data["Depression State"] = data["Total_Score"].apply(classify_depression)

# %%
data.head()
# Out:
#                Sleep                 Appetite  \
# 0  Less than 3 hours  Significantly decreased
# 1          3–5 hours  Significantly increased
# 2  More than 9 hours       Slightly decreased
# 3  Less than 3 hours  Significantly decreased
# 4          3–5 hours  Significantly increased
#
#                                             Interest  \
# 0                  I still find joy in my activities
# 1  I feel completely disengaged and indifferent t...
# 2           I notice a dulling of interest sometimes
# 3                  I still find joy in my activities
# 4  I feel completely disengaged and indifferent t...
#
#                                              Fatigue  \
# 0  I am frequently exhausted and struggle to get ...
# 1      I feel energized and capable most of the time
# 2                I sometimes feel drained but manage
# 3  I am frequently exhausted and struggle to get ...
# 4      I feel energized and capable most of the time
#
#                                        Worthlessness  \
# 0  I frequently feel like a failure and question ...
# 1          I generally feel confident and worthwhile
# 2                        I occasionally doubt myself
# 3  I frequently feel like a failure and question ...
# 4          I generally feel confident and worthwhile
#
#                                        Concentration  \
# 0                    I focus easily and stay engaged
# 1  Concentration is almost impossible, and I feel...
# 2     Distractions sometimes interfere with my focus
# 3                    I focus easily and stay engaged
# 4  Concentration is almost impossible, and I feel...
#
#                                            Agitation    Suicidal Ideation  \
# 0  I am frequently overwhelmed by restlessness an...    Pretty much daily
# 1                            I feel calm and settled                Never
# 2               I sometimes feel restless or fidgety  Once in a blue moon
# 3  I am frequently overwhelmed by restlessness an...    Pretty much daily
# 4                            I feel calm and settled                Never
#
#              Sleep Disturbance                    Aggression  \
# 0            Sleep like a baby        Angry almost every day
# 1  Barely sleep at all anymore                     Very calm
# 2   Occasionally toss and turn  A little irritated sometimes
# 3            Sleep like a baby        Angry almost every day
# 4  Barely sleep at all anymore                     Very calm
#
#                       Panic Attacks                           Hopelessness  \
# 0  Almost every day, out of nowhere     Always – I feel hopeless every day
# 1                     Never happens  Almost never – I usually feel hopeful
# 2       Rarely, maybe once or twice  Sometimes – I feel stuck now and then
# 3  Almost every day, out of nowhere     Always – I feel hopeless every day
# 4                     Never happens  Almost never – I usually feel hopeful
#
#                           Restlessness  \
# 0  I constantly feel uneasy or on edge
# 1         I feel calm most of the time
# 2            It happens, but not often
# 3  I constantly feel uneasy or on edge
# 4         I feel calm most of the time
#
#                                           Low Energy     Depression State
# 0  I frequently feel completely exhausted and inc...  Moderate Depression
# 1  I usually feel energized and motivated through...  Moderate Depression
# 2  I sometimes feel a bit tired, but it doesn't a...    Severe Depression
# 3  I frequently feel completely exhausted and inc...  Moderate Depression
# 4  I usually feel energized and motivated through...  Moderate Depression

# %%
# Create a dictionary to hold encoders for each column
New = {}
new_data = data.copy()

# Apply LabelEncoder to every column
for column in new_data.columns:
    le = LabelEncoder()
    new_data[column] = le.fit_transform(new_data[column])
    New[column] = le  # Save the encoder for later decoding

# %%
new_data.head()
# Out:
#    Sleep  Appetite  Interest  Fatigue  Worthlessness  Concentration  \
# 0      3         1         3        0              0              2
# 1      0         2         0        1              1              0
# 2      4         3         1        3              2              1
# 3      3         1         3        0              0              2
# 4      0         2         0        1              1              0
#
#    Agitation  Suicidal Ideation  Sleep Disturbance  Aggression  Panic Attacks  \
# 0          0                  4                  4           1              0
# 1          1                  2                  1           4              1
# 2          3                  3                  2           0              3
# 3          0                  4                  4           1              0
# 4          1                  2                  1           4              1
#
#    Hopelessness  Restlessness  Low Energy  Depression State
# 0             1             0           0                 2
# 1             0             2           3                 2
# 2             4             3           2                 3
# 3             1             0           0                 2
# 4             0             2           3                 2

# %%
# X = all columns except target
X = new_data.drop('Depression State', axis=1)

# y = the target column
y = new_data['Depression State']

# Encode y
target_encoder = LabelEncoder()
y_encoded = target_encoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

# %%
rf_model = RandomForestClassifier(random_state=42, class_weight='balanced')
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)

print("📊 Random Forest Results:")
print("Accuracy:", accuracy_score(y_test, rf_preds))
print(classification_report(y_test, rf_preds))

# Feature Importance
print("\n🌲 Feature Importance (Random Forest):")
importances = rf_model.feature_importances_
for name, score in zip(X.columns, importances):
    print(f"{name}: {score * 100:.3f}%")



log_model = LogisticRegression(max_iter=1000, class_weight='balanced')
log_model.fit(X_train, y_train)
log_preds = log_model.predict(X_test)

print("\n📊 Logistic Regression Results:")
print("Accuracy:", accuracy_score(y_test, log_preds))
print(classification_report(y_test, log_preds))
# Out:
# 📊 Random Forest Results:
# Accuracy: 0.8395061728395061
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.68      0.56      0.61        34
#            2       0.79      0.84      0.82        69
#            3       0.96      1.00      0.98        53
#
#     accuracy                           0.84       162
#    macro avg       0.86      0.85      0.85       162
# weighted avg       0.83      0.84      0.83       162
#
#
# 🌲 Feature Importance (Random Forest):
# Sleep: 3.869%
# Appetite: 12.860%
# Interest: 8.059%
# Fatigue: 5.699%
# Worthlessness: 8.616%
# Concentration: 14.584%
# Agitation: 9.955%
# Suicidal Ideation: 1.279%
# Sleep Disturbance: 5.040%
# Aggression: 2.712%
# Panic Attacks: 4.849%
# Hopelessness: 6.743%
# Restlessness: 5.949%
# Low Energy: 9.786%
#
# 📊 Logistic Regression Results:
# Accuracy: 0.845679012345679
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.74      0.50      0.60        34
#            2       0.78      0.88      0.83        69
#            3       0.96      1.00      0.98        53
#
#     accuracy                           0.85       162
#    macro avg       0.87      0.85      0.85       162
# weighted avg       0.84      0.85      0.84       162

# %%
# Get feature importances directly from the model
importances = rf_model.feature_importances_
features = X_train.columns

# Create a DataFrame for easy sorting and plotting
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)
colors = plt.cm.viridis(np.linspace(0, 1, len(features)))
# Plot
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'], color=colors)
plt.xlabel('Importance')
plt.title('Feature Importance (Random Forest)')
plt.gca().invert_yaxis()  # Optional: puts most important on top
plt.tight_layout()
plt.show()

# %%
y_pred = rf_model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
y_pred = rf_model.predict(X_test)

plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # diagonal line
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Prediction vs Actual')
plt.show()

# %%
label_map = {0: "No Depression", 1: "Mild", 2: "Moderate", 3: "Severe"}
y_named = y.map(label_map)

y_named.value_counts().plot.pie(autopct='%1.1f%%', figsize=(6,6))
plt.title('Class Distribution')
plt.ylabel('')
plt.show()

# %%
import pickle

with open('rf_model_and_encoders.pkl', 'wb') as f:
    pickle.dump({
        'model': rf_model,
        'feature_encoders': New,
        'target_encoder': target_encoder
    }, f)

# %%
import pickle

with open('log_model_and_encoders.pkl', 'wb') as f:
    pickle.dump({
        'model': log_model,
        'feature_encoders': New,
        'target_encoder': target_encoder
    }, f)
